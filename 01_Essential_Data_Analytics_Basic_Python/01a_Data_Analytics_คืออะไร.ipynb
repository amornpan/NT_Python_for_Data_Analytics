# %% [markdown]
# # 🤔 Data Analytics คืออะไร?
#
# **บทเรียนที่ 1.1 - ความรู้เบื้องต้น**
#
# ---

# %% [markdown]
# ## 🎯 วัตถุประสงค์
#
# หลังจากเรียนบทนี้แล้ว ผู้เรียนจะสามารถ:
# - อธิบายความหมายของ Data Analytics ได้
# - เข้าใจความสำคัญของการวิเคราะห์ข้อมูลในธุรกิจ
# - ยกตัวอย่างการใช้งานในชีวิตประจำวันได้

# %% [markdown]
# ## 📖 ความหมาย
#
# **การวิเคราะห์ข้อมูล (Data Analytics)** คือ:
#
# > กระบวนการตรวจสอบ ทำความสะอาด เปลี่ยนแปลง และสร้างแบบจำลองจากข้อมูล เพื่อค้นหาข้อมูลที่มีประโยชน์ สนับสนุนการตัดสินใจ และช่วยในการสรุปผล
#
# ### 💡 เปรียบเทียบง่ายๆ
#
# คิดเหมือนการเป็น **นักสืบ** ที่ต้อง:
# - 🔍 **สืบหา** - เก็บรวบรวมหลักฐาน (ข้อมูล)
# - 🧐 **วิเคราะห์** - ตรวจสอบและหาความเชื่อมโยง
# - 🎯 **สรุป** - หาคำตอบและให้คำแนะนำ

# %% [markdown]
# ## 🌟 ทำไมต้อง Data Analytics?
#
# ### ในยุคดิจิทัล เรามีข้อมูลมากมาย แต่...
# - 📊 **ข้อมูลดิบ** ≠ **ข้อมูลเชิงลึก**
# - 🔢 ตัวเลขเยอะ แต่ไม่รู้ความหมาย
# - 💭 ต้องการคำตอบจากข้อมูลที่มี
#
# ### Data Analytics ช่วย:
# ✅ เปลี่ยนข้อมูลเป็นความรู้
# ✅ ช่วยตัดสินใจด้วยหลักฐาน
# ✅ ลดความเสี่ยงในการตัดสินใจ
# ✅ เพิ่มประสิทธิภาพธุรกิจ

# %%
# ตัวอย่างง่ายๆ: จากข้อมูลดิบสู่ข้อมูลเชิงลึก

# ข้อมูลดิบ: ยอดขายรายวัน
daily_sales = [12000, 15000, 8000, 22000, 18000, 25000, 20000]
days = ['จันทร์', 'อังคาร', 'พุธ', 'พฤหัส', 'ศุกร์', 'เสาร์', 'อาทิตย์']

print("📊 ข้อมูลดิบ - ยอดขายรายวัน:")
for day, sales in zip(days, daily_sales):
    print(f"{day}: {sales:,} บาท")

print("\n" + "="*40)
print("🧠 ข้อมูลเชิงลึกหลังจากวิเคราะห์:")

# วิเคราะห์เบื้องต้น
total_sales = sum(daily_sales)
avg_sales = total_sales / len(daily_sales)
best_day_index = daily_sales.index(max(daily_sales))
worst_day_index = daily_sales.index(min(daily_sales))

print(f"💰 ยอดขายรวม 7 วัน: {total_sales:,} บาท")
print(f"📈 ยอดขายเฉลี่ยต่อวัน: {avg_sales:,.0f} บาท")
print(f"🏆 วันที่ขายดีที่สุด: {days[best_day_index]} ({daily_sales[best_day_index]:,} บาท)")
print(f"📉 วันที่ขายต่ำที่สุด: {days[worst_day_index]} ({daily_sales[worst_day_index]:,} บาท)")

print("\n💡 ข้อมูลเชิงลึก:")
print("   - วันเสาร์ขายดีที่สุด (วันหยุด)")
print("   - วันพุธขายต่ำที่สุด (กลางสัปดาห์)")
print("   - ควรเพิ่มโปรโมชันในวันกลางสัปดาห์")

# %% [markdown]
# ## 🏢 ตัวอย่างการใช้งานในธุรกิจจริง
#
# ### 🛒 **ร้านค้าออนไลน์**
# - วิเคราะห์สินค้าไหนขายดี
# - หาเวลาที่ลูกค้าออนไลน์มากที่สุด
# - ปรับราคาให้เหมาะสม
#
# ### 🏦 **ธนาคาร**
# - ประเมินความเสี่ยงลูกค้าผิดนัดชำระ
# - ตรวจจับธุรกรรมผิดปกติ
# - แนะนำผลิตภัณฑ์ที่เหมาะกับลูกค้า
#
# ### 🚗 **บริษัทขนส่ง**
# - หาเส้นทางที่เร็วที่สุด
# - คำนวณค่าน้ำมันที่ประหยัดที่สุด
# - พยากรณ์ความต้องการขนส่ง

# %% [markdown]
# ## 🏦 กรณีศึกษา: Lending Club
#
# **Lending Club** เป็นแพลตฟอร์มให้กู้ยืมเงินออนไลน์ที่ใช้ Data Analytics ทุกขั้นตอน:
#
# ### 📊 ข้อมูลที่มี:
# - ข้อมูลส่วนตัวของผู้กู้
# - ประวัติการเงิน
# - จุดประสงค์การกู้
# - ประวัติการชำระหนี้
#
# ### 🎯 เป้าหมาย:
# - ลดความเสี่ยงการผิดนัดชำระ
# - เพิ่มผลกำไรจากดอกเบี้ย
# - ให้บริการที่ดีกับลูกค้า

# %%
# ตัวอย่างข้อมูล Lending Club แบบง่าย

print("🏦 ตัวอย่างข้อมูลลูกค้า Lending Club")
print("="*50)

# ข้อมูลลูกค้า 3 คน
customers = [
    {
        'ชื่อ': 'คุณ A',
        'อายุ': 35,
        'รายได้': 50000,
        'ประวัติเครดิต': 'ดี',
        'จุดประสงค์': 'ซื้อรถ'
    },
    {
        'ชื่อ': 'คุณ B',
        'อายุ': 28,
        'รายได้': 30000,
        'ประวัติเครดิต': 'ปานกลาง',
        'จุดประสงค์': 'ผ่อนหนี้'
    },
    {
        'ชื่อ': 'คุณ C',
        'อายุ': 42,
        'รายได้': 70000,
        'ประวัติเครดิต': 'ดีมาก',
        'จุดประสงค์': 'ปรับปรุงบ้าน'
    }
]

for i, customer in enumerate(customers, 1):
    print(f"ลูกค้าคนที่ {i}:")
    for key, value in customer.items():
        print(f"  {key}: {value}")
    print()

print("🤔 คำถามสำหรับวิเคราะห์:")
print("   - ใครมีความเสี่ยงต่ำที่สุด?")
print("   - ควรให้อัตราดอกเบี้ยเท่าไหร่?")
print("   - ควรอนุมัติเงินกู้ให้ใครบ้าง?")

# %% [markdown]
# ## 🎯 แบบฝึกหัดเบื้องต้น
#
# ### 💭 คำถามให้คิด:
#
# 1. **ในชีวิตประจำวันของคุณ มีการใช้ Data Analytics ที่ไหนบ้าง?**
#    - Google Maps หาเส้นทาง
#    - Netflix แนะนำหนัง
#    - Facebook โฆษณาเฉพาะเจาะจง
#
# 2. **ถ้าคุณเป็นเจ้าของร้านกาแฟ จะใช้ Data Analytics อย่างไร?**
#
# 3. **ข้อมูลอะไรที่คิดว่าสำคัญที่สุดสำหรับธุรกิจให้กู้ยืมเงิน?**

# %%
# 🏃‍♂️ Mini Exercise: ลองวิเคราะห์ข้อมูลร้านกาแฟ

# ข้อมูลยอดขายเครื่องดื่มในร้านกาแฟ
drinks = ['Americano', 'Latte', 'Cappuccino', 'Mocha', 'Espresso']
sales_count = [45, 67, 23, 34, 12]  # จำนวนแก้วที่ขายได้
price = [60, 80, 75, 85, 50]  # ราคาต่อแก้ว

print("☕ ข้อมูลยอดขายร้านกาแฟวันนี้")
print("="*40)

# TODO: ลองเขียนโค้ดเพื่อหา
# 1. เครื่องดื่มไหนขายดีที่สุด?
# 2. เครื่องดื่มไหนทำรายได้มากที่สุด?
# 3. รายได้รวมทั้งหมด?

print("💭 ลองวิเคราะห์ข้อมูลนี้ดูนะ!")
print("🎯 เป้าหมาย: หาเครื่องดื่มที่ขายดี และคำนวณรายได้")

# %% [markdown]
# ## 📝 สรุป
#
# ### ✅ สิ่งที่เราได้เรียนรู้:
#
# 1. **Data Analytics** = การเปลี่ยนข้อมูลเป็นความรู้เพื่อการตัดสินใจ
#
# 2. **ความสำคัญ**:
#    - ช่วยตัดสินใจด้วยหลักฐาน
#    - ลดความเสี่ยง
#    - เพิ่มประสิทธิภาพ
#
# 3. **การประยุกต์ใช้** - มีอยู่ทุกที่ในชีวิตประจำวันและธุรกิจ
#
# ### 🚀 บทถัดไป:
# เราจะเรียนรู้เกี่ยวกับ **ประเภทของการวิเคราะห์ข้อมูล** 4 แบบ ที่ตอบคำถามต่างกัน
#
# ---
# *💡 เคล็ดลับ: ลองสังเกตการใช้ Data Analytics รอบตัวคุณในชีวิตประจำวัน!*
