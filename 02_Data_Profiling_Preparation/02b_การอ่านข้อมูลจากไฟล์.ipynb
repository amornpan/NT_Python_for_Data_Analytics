# %%
# 🏃‍♂️ Mini Exercise: การอ่านและตรวจสอบข้อมูล

print("🏃‍♂️ แบบฝึกหัด: การอ่านและตรวจสอบข้อมูล")
print("="*55)

# สมมติว่าเราได้รับข้อมูลลูกค้าธนาคารในรูปแบบต่างๆ
# ให้ลองวิเคราะห์ปัญหาและหาวิธีแก้

# ข้อมูลที่มีปัญหา (จำลอง)
problematic_data = """
customer_id,name,age,income,loan_amount,status
C001,สมใส,25,45000,150000,อนุมัติ
C002,John,N/A,60000,200000,รอพิจารณา
C003,มารี,,55000,180000,ปฏิเสธ
C004,David,35,NULL,220000,อนุมัติ
C005,สุดา,28,48000,,รอพิจารณา
"""

# TODO: ลองแก้ปัญหาเหล่านี้
# 1. อ่านข้อมูลที่มีค่าว่างในรูปแบบต่างๆ (N/A, NULL, ว่าง)
# 2. ตรวจสอบและแสดงจำนวนค่าว่างในแต่ละคอลัมน์
# 3. หาวิธีจัดการกับค่าว่าง
# 4. สร้างสรุปข้อมูลที่สะอาดแล้ว

print("💭 ลองแก้ปัญหาการอ่านข้อมูลนี้ดูนะ!")
print("🎯 เป้าหมาย: จัดการกับข้อมูลที่ไม่สมบูรณ์")
print("💡 เคล็ดลับ: ใช้ na_values, isnull(), fillna()")

# %% [markdown]
# ## 📚 สรุป
#
# ### ✅ สิ่งที่เราได้เรียนรู้:
#
# 1. **การอ่านไฟล์ข้อมูล**:
#    - CSV: `pd.read_csv()`
#    - Excel: `pd.read_excel()`
#    - พารามิเตอร์สำคัญต่างๆ
#
# 2. **การจัดการปัญหาการอ่านไฟล์**:
#    - ปัญหา encoding ภาษาไทย
#    - ไฟล์ขนาดใหญ่
#    - ตัวแยกที่ไม่ใช่ comma
#    - ค่าว่างในรูปแบบต่างๆ
#
# 3. **การตรวจสอบคุณภาพข้อมูล**:
#    - ขนาดข้อมูล (.shape)
#    - ค่าว่าง (.isnull())
#    - ข้อมูลซ้ำ (.duplicated())
#    - สถิติเบื้องต้น (.describe())
#
# 4. **การบันทึกข้อมูล**:
#    - `.to_csv()`, `.to_excel()`, `.to_json()`
#    - การเลือกคอลัมน์ที่สำคัญ
#    - การจัดการ encoding
#
# 5. **ข้อมูล Lending Club**:
#    - โครงสร้างข้อมูลที่ซับซ้อน
#    - คอลัมน์สำคัญที่ควรใส่ใจ
#    - การเตรียมข้อมูลสำหรับการวิเคราะห์
#
# ### 🚀 บทถัดไป:
# เราจะเรียนรู้การ **ทำ Data Profiling** - การวิเคราะห์ข้อมูลเชิงลึกมากขึ้น
#
# ---
# *💡 เคล็ดลับ: การอ่านข้อมูลที่ถูกต้องเป็นจุดเริ่มต้นของการวิเคราะห์ที่ดี!*
